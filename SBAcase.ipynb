# %%
# Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import matplotlib.pyplot as plt # Visualization
import seaborn as sns #Visualization

# %%
df1= pd.read_csv('C:/Users/M V N POOJITHA/Downloads/SBAcase.csv') #loading dataset
print('\nNumber of rows and columns in the data set: ',df1.shape)  #displaying rows and cols
print('')
df1.head(2) #display dataset
# Out:
# Number of rows and columns in the data set:  (2102, 35)
#    Selected  LoanNr_ChkDgt                      Name      City State    Zip  \
# 0         0     1004285007  SIMPLEX OFFICE SOLUTIONS   ANAHEIM    CA  92801
# 1         1     1004535010         DREAM HOME REALTY  TORRANCE    CA  90505
#
#                       Bank BankState   NAICS  ApprovalDate   ...    \
# 0  CALIFORNIA BANK & TRUST        CA  532420         15074   ...
# 1  CALIFORNIA BANK & TRUST        CA  531210         15130   ...
#
#    ChgOffPrinGr  GrAppv  SBA_Appv  New  RealEstate  Portion  Recession  \
# 0             0   30000     15000    0           0      0.5          0
# 1             0   30000     15000    0           0      0.5          1
#
#    daysterm       xx Default
# 0      1080  16175.0       0
# 1      1680  17658.0       0
#
# [2 rows x 35 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2102 entries, 0 to 2101
# Data columns (total 35 columns):
# Selected             2102 non-null int64
# LoanNr_ChkDgt        2102 non-null int64
# Name                 2102 non-null object
# City                 2102 non-null object
# State                2102 non-null object
# Zip                  2102 non-null int64
# Bank                 2099 non-null object
# BankState            2099 non-null object
# NAICS                2102 non-null int64
# ApprovalDate         2102 non-null int64
# ApprovalFY           2102 non-null int64
# Term                 2102 non-null int64
# NoEmp                2102 non-null int64
# NewExist             2101 non-null float64
# CreateJob            2102 non-null int64
# RetainedJob          2102 non-null int64
# FranchiseCode        2102 non-null int64
# UrbanRural           2102 non-null int64
# RevLineCr            2100 non-null object
# LowDoc               2099 non-null object
# ChgOffDate           697 non-null float64
# DisbursementDate     2099 non-null float64
# DisbursementGross    2102 non-null int64
# BalanceGross         2102 non-null int64
# MIS_Status           2102 non-null object
# ChgOffPrinGr         2102 non-null int64
# GrAppv               2102 non-null int64
# SBA_Appv             2102 non-null int64
# New                  2102 non-null int64
# RealEstate           2102 non-null int64
# Portion              2102 non-null float64
# Recession            2102 non-null int64
# daysterm             2102 non-null int64
# xx                   2099 non-null float64
# Default              2102 non-null int64
# dtypes: float64(5), int64(22), object(8)
# memory usage: 574.8+ KB

# %%
print ("Rows     : " ,df1.shape[0])   #print no.of rows
print ("Columns  : " ,df1.shape[1])   #print no.of cols
print ("\nFeatures : \n" ,df1.columns.tolist())   #print columns list
print ("\nMissing values :  ", df1.isnull().sum().values.sum())    #print missing values
print ("\nUnique values :  \n",df1.nunique())   #print unique values
# Out:
# Rows     :  2102
# Columns  :  35
#
# Features :
#  ['Selected', 'LoanNr_ChkDgt', 'Name', 'City', 'State', 'Zip', 'Bank', 'BankState', 'NAICS', 'ApprovalDate', 'ApprovalFY', 'Term', 'NoEmp', 'NewExist', 'CreateJob', 'RetainedJob', 'FranchiseCode', 'UrbanRural', 'RevLineCr', 'LowDoc', 'ChgOffDate', 'DisbursementDate', 'DisbursementGross', 'BalanceGross', 'MIS_Status', 'ChgOffPrinGr', 'GrAppv', 'SBA_Appv', 'New', 'RealEstate', 'Portion', 'Recession', 'daysterm', 'xx', 'Default']
#
# Missing values :   1423
#
# Unique values :
#  Selected                2
# LoanNr_ChkDgt        2102
# Name                 2005
# City                  519
# State                   1
# Zip                   814
# Bank                  154
# BankState              21
# NAICS                  24
# ApprovalDate         1367
# ApprovalFY             24
# Term                  170
# NoEmp                  83
# NewExist                3
# CreateJob              43
# RetainedJob            62
# FranchiseCode          33
# UrbanRural              3
# RevLineCr               4
# LowDoc                  5
# ChgOffDate            503
# DisbursementDate      321
# DisbursementGross    1182
# BalanceGross            1
# MIS_Status              2
# ChgOffPrinGr          615
# GrAppv                659
# SBA_Appv              755
# New                     2
# RealEstate              2
# Portion                31
# Recession               2
# daysterm              170
# xx                   1212
# Default                 2
# dtype: int64

# %%
df1.describe()
# Out:
#           Selected  LoanNr_ChkDgt           Zip          NAICS  ApprovalDate  \
# count  2102.000000   2.102000e+03   2102.000000    2102.000000   2102.000000
# mean      0.500000   4.469172e+09  92698.612274  531630.902950  16179.587060
# std       0.500119   2.530069e+09   1878.208435     521.836986   1454.931276
# min       0.000000   1.004285e+09  65757.000000  531110.000000  10554.000000
# 25%       0.000000   2.392978e+09  91402.000000  531210.000000  15695.750000
# 50%       0.500000   3.621730e+09  92559.500000  531312.000000  16556.000000
# 75%       1.000000   6.551607e+09  94127.750000  532230.000000  17149.750000
# max       1.000000   9.958873e+09  96161.000000  533110.000000  18911.000000
#
#         ApprovalFY         Term        NoEmp     NewExist    CreateJob  \
# count  2102.000000  2102.000000  2102.000000  2101.000000  2102.000000
# mean   2004.035680   126.980495    10.150809     1.153736     2.549952
# std       4.006321    93.798944    34.402420     0.362099     8.010175
# min    1989.000000     0.000000     0.000000     0.000000     0.000000
# 25%    2003.000000    60.000000     2.000000     1.000000     0.000000
# 50%    2005.000000    84.000000     3.000000     1.000000     0.000000
# 75%    2007.000000   240.000000     8.000000     1.000000     2.000000
# max    2012.000000   306.000000   650.000000     2.000000   130.000000
#
#           ...       ChgOffPrinGr        GrAppv      SBA_Appv          New  \
# count     ...       2.102000e+03  2.102000e+03  2.102000e+03  2102.000000
# mean      ...       2.002908e+04  2.330641e+05  1.891759e+05     0.154139
# std       ...       7.543229e+04  3.436310e+05  2.989268e+05     0.361168
# min       ...       0.000000e+00  4.500000e+03  2.250000e+03     0.000000
# 25%       ...       0.000000e+00  3.000000e+04  1.500000e+04     0.000000
# 50%       ...       0.000000e+00  6.100000e+04  4.168000e+04     0.000000
# 75%       ...       1.507350e+04  3.000000e+05  2.397562e+05     0.000000
# max       ...       1.509550e+06  2.350000e+06  2.115000e+06     1.000000
#
#         RealEstate      Portion    Recession     daysterm            xx  \
# count  2102.000000  2102.000000  2102.000000  2102.000000   2099.000000
# mean      0.274500     0.671055     0.068506  3809.414843  20076.896141
# std       0.446368     0.186519     0.252673  2813.968318   2854.510377
# min       0.000000     0.296770     0.000000     0.000000  11524.000000
# 25%       0.000000     0.500000     0.000000  1800.000000  18316.500000
# 50%       0.000000     0.500000     0.000000  2520.000000  19270.000000
# 75%       1.000000     0.850000     0.000000  7200.000000  22335.000000
# max       1.000000     1.000000     1.000000  9180.000000  27598.000000
#
#            Default
# count  2102.000000
# mean      0.326356
# std       0.468991
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000
#
# [8 rows x 27 columns]

# %%
#checking for missing values
plt.figure(figsize=(14,4))
sns.heatmap(df1.isnull(),cbar=False,cmap='viridis',yticklabels=False)
plt.title('Missing value in the dataset');

# %%
# Function to calculate missing values by column
def missing_values_table(df):
        mis_val = df.isnull().sum()   # Total missing values
        mis_val_percent = 100 * df.isnull().sum() / len(df)  # Percentage of missing values
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)    # Make a table with the results
        mis_val_table_ren_columns = mis_val_table.rename(columns={0 :'Missing Values', 1 :'% of Total Values'}) # Rename the cols
        # Sort the table by percentage of missing descending
        mis_val_table_ren_columns = mis_val_table_ren_columns[mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        # Print some summary information
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"  "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        # Return the dataframe with missing information
        return mis_val_table_ren_columns
missing_values_table(df1)
# Out:
# Your selected dataframe has 35 columns.
# There are 8 columns that have missing values.
#                   Missing Values  % of Total Values
# ChgOffDate                  1405               66.8
# Bank                           3                0.1
# BankState                      3                0.1
# LowDoc                         3                0.1
# DisbursementDate               3                0.1
# xx                             3                0.1
# RevLineCr                      2                0.1
# NewExist                       1                0.0

# %%
from sklearn.model_selection import train_test_split
# Split Into Training and Testing Sets

# Separate out the features and targets
features = df1.drop(columns='MIS_Status')
targets = pd.DataFrame(df1['MIS_Status'])

# Split into 80% training and 20% testing set
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size = 0.2, random_state = 42)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1681, 34)
# (421, 34)
# (1681, 1)
# (421, 1)
